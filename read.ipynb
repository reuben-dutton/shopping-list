# %%
import json

import models

# %%
path = r'M:\dev\shopping-list\recipes\easy_greek_meatballs.json'

with open(path, mode='r') as j:
    data = json.load(j)

recipe = models.Recipe.model_validate(data)

# %%
recipe
# Out:
# Recipe(name='Easy Greek meatballs with feta cheese', ingredients=[Ingredient(measurement=500g, name='lamb', part=None, variety=None, intrinsics=['ground']), Ingredient(measurement=500g, name='beef', part=None, variety=None, intrinsics=['ground']), Ingredient(measurement=1 cup, name='breadcrumbs', part=None, variety=None, intrinsics=['fresh']), Ingredient(measurement=2 pieces, name='eggs', part=None, variety=None, intrinsics=['large']), Ingredient(measurement=½ cup, name='feta cheese', part=None, variety=None, intrinsics=['crumbled']), Ingredient(measurement=1 whole, name='onion', part=None, variety='red', intrinsics=['small', 'finely minced']), Ingredient(measurement=2 cloves, name='garlic', part=None, variety=None, intrinsics=['crushed']), Ingredient(measurement=1 whole, name='lemon', part='zest', variety=None, intrinsics=[]), Ingredient(measurement=3 tsp, name='oregano', part=None, variety=None, intrinsics=['dried']), Ingredient(measurement=2 tsp, name='rosemary', part=None, variet
# ...
